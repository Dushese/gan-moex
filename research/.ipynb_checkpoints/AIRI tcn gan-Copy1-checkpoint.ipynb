# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("..")
print(os.getcwd(), os.listdir())
# Out:
# C:\Users\an.v.potapov\Desktop\учеба\ФТИАД\курсач\gan_moex ['.git', '.gitignore', '.idea', '.ipynb_checkpoints', '.pytest_cache', 'AIRI', 'compare with airi', 'dashboard', 'data', 'genrisk', 'library', 'lightning_logs', 'models', 'README.MD', 'research', 'setup.py', 'test.egg-info', 'TSGBench', 'wandb']

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import DataLoader
import seaborn as sns
from torch import optim
import torch
import wandb

# %%
from library.dataset import get_pytorch_datataset, BATCH_SIZE

df_returns_real, dataset, dataloader, N_ASSETS, WINDOW_SIZE = get_pytorch_datataset()

print(f'\nDataset length: {len(dataset)}')
print(f'Number of assets: {N_ASSETS}')
sample_batch = next(iter(dataloader))
assert sample_batch.size() == (BATCH_SIZE, N_ASSETS, WINDOW_SIZE)
print(f'Sample batch: {sample_batch.size()}')
# Out:
# AAAAAAA data True data\tickers.csv True
# Chosen tickers: ['LKOH', 'SBER', 'SBERP', 'VTBR', 'MOEX']
# Length before dropping NaNs: 2603
# Length after dropping NaNs: 2577
#
# Dataset length: 2217
# Number of assets: 5
# Sample batch: torch.Size([256, 5, 360])

# %%
df_returns_real.cumsum().plot()
plt.show()

# %%
from genrisk.generation import TCNGAN

# %%
N_EPOCHS = 400
window_size = 360
# KERNEL_SIZE = 3

BATCH = 16


for KERNEL_SIZE in ([3, 5, 7]):
    wandb.init(
                project="gan_moex",  # Название проекта в W&B
                name=f"AIRI генерация log доходности акций",         # AIRI генерация log доходности акций
                
                config={              # Сохраняем гиперпараметры
                    "learning_rate": 0.001,
                    "batch_size": BATCH,
                    "architecture": "TCN-GAN AIRI",
                    "dataset": 'log-returs',
                    "N_EPOCHS": N_EPOCHS,
                    "window_size": window_size,
                    "kernel_size": KERNEL_SIZE,
                    "custom_loss": True,
                }
            )
    
    gen = TCNGAN(
        target_columns=df_returns_real.columns.tolist(), 
        conditional_columns=[],
        hidden_dim=16,
        latent_dim=1,
        num_layers=2,
        kernel_size=KERNEL_SIZE,
        num_disc_steps=3,
        window_size=window_size,
        batch_size=BATCH,
        num_epochs=N_EPOCHS,
        verbose=True,
        lr=0.001,
    )
    gen.fit(df_returns_real)

    fake_data = gen.sample(df_returns_real.iloc[:100], n_samples=1)
    
    fake_data[0].plot()
    
    plt.title(f'batch_size = {BATCH}')
    wandb.log({"generated_samples": wandb.Image(plt)})
    plt.show()
    
    fake_data[0].cumsum().plot()
    
    plt.title(f'batch_size = {BATCH}')
    wandb.log({"cumsum_generated_samples": wandb.Image(plt)})
    plt.show()
    
    torch.save(gen.model.gen.state_dict(), f'models/AIRI/TCN/N_EPOCHS_{N_EPOCHS}_KERNEL_SIZE_{KERNEL_SIZE}_window_size_{window_size}.pth')
    
    wandb.finish()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: avpotapov_5 (avpotapov_5-hse) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>C:\Users\an.v.potapov\Desktop\учеба\ФТИАД\курсач\gan_moex\wandb\run-20250524_174642-dobsfmyx</code>
# Syncing run <strong><a href='https://wandb.ai/avpotapov_5-hse/gan_moex/runs/dobsfmyx' target="_blank">AIRI генерация log доходности акций</a></strong> to <a href='https://wandb.ai/avpotapov_5-hse/gan_moex' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/avpotapov_5-hse/gan_moex' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex</a>
#  View run at <a href='https://wandb.ai/avpotapov_5-hse/gan_moex/runs/dobsfmyx' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex/runs/dobsfmyx</a>
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Python\Lib\site-packages\lightning\pytorch\loggers\wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#
#   | Name | Type              | Params | Mode
# ---------------------------------------------------
# 0 | gen  | _TCNGenerator     | 2.5 K  | train
# 1 | disc | _TCNDiscriminator | 2.7 K  | train
# ---------------------------------------------------
# 5.3 K     Trainable params
# 0         Non-trainable params
# 5.3 K     Total params
# 0.021     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# Training: |                                                                                                 | …
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# attempt to get argmax of an empty sequence
# `Trainer.fit` stopped: `max_epochs=400` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>correlation_delta</td><td>▅█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▁▂▂▂▂▂▁▁▁▂▁▂▂▁▁▂▂▂▂</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>fid</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_delta</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_disc_loss</td><td>▁▁▂▄▆▇▇█████████████████████████████████</td></tr><tr><td>train_gen_loss</td><td>█▄▅▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>correlation_delta</td><td>0.03461</td></tr><tr><td>epoch</td><td>399</td></tr><tr><td>fid</td><td>0.00198</td></tr><tr><td>mean_delta</td><td>0.00243</td></tr><tr><td>train_disc_loss</td><td>0.69306</td></tr><tr><td>train_gen_loss</td><td>1.18119</td></tr><tr><td>trainer/global_step</td><td>55593</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AIRI генерация log доходности акций</strong> at: <a href='https://wandb.ai/avpotapov_5-hse/gan_moex/runs/dobsfmyx' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex/runs/dobsfmyx</a><br> View project at: <a href='https://wandb.ai/avpotapov_5-hse/gan_moex' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex</a><br>Synced 5 W&B file(s), 2 media file(s), 800 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250524_174642-dobsfmyx\logs</code>
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>C:\Users\an.v.potapov\Desktop\учеба\ФТИАД\курсач\gan_moex\wandb\run-20250525_062746-yqhgr4qi</code>
# Syncing run <strong><a href='https://wandb.ai/avpotapov_5-hse/gan_moex/runs/yqhgr4qi' target="_blank">AIRI генерация log доходности акций</a></strong> to <a href='https://wandb.ai/avpotapov_5-hse/gan_moex' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/avpotapov_5-hse/gan_moex' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex</a>
#  View run at <a href='https://wandb.ai/avpotapov_5-hse/gan_moex/runs/yqhgr4qi' target="_blank">https://wandb.ai/avpotapov_5-hse/gan_moex/runs/yqhgr4qi</a>
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Python\Lib\site-packages\lightning\pytorch\loggers\wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#
#   | Name | Type              | Params | Mode
# ---------------------------------------------------
# 0 | gen  | _TCNGenerator     | 4.1 K  | train
# 1 | disc | _TCNDiscriminator | 4.4 K  | train
# ---------------------------------------------------
# 8.5 K     Trainable params
# 0         Non-trainable params
# 8.5 K     Total params
# 0.034     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# Training: |                                                                                                 | …

# %%
fake_data = gen.sample(df_returns_real, n_samples=10)
fake_data[0].head()
# Out:
#                 LKOH      SBER     SBERP      VTBR      MOEX
# date
# 2013-04-05  0.067366  0.351358 -0.064038  0.175481  0.374686
# 2013-04-08  0.259969  0.273771 -0.049847 -0.051569  0.398581
# 2013-04-09  0.159042  0.234306 -0.070234  0.020737  0.430525
# 2013-04-10  0.107999  0.196515 -0.058914 -0.012649  0.351933
# 2013-04-11  0.120014  0.210781 -0.089339  0.065880  0.451478

# %%
plt.figure(figsize=(12, 3))
for fake in fake_data:
    fake.cumsum().plot()

# %%
df_returns_real.iloc[:100].cumsum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
torch.abs(torch.rand(3, 4, 5)[-1].corrcoef()).sum()
# Out:
# tensor(7.0182)

# %%
torch.abs(torch.rand(3, 4, 5).mean(axis=1))
# Out:
# tensor([[0.5533, 0.3956, 0.6158, 0.5669, 0.5612],
#         [0.4262, 0.6352, 0.4849, 0.4541, 0.2660],
#         [0.2210, 0.4104, 0.3990, 0.4670, 0.5107]])

# %%
torch.tensor([1, 2, 3]).detach().to_numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 torch.tensor([1, 2, 3]).detach().to_numpy()
#
# AttributeError: 'Tensor' object has no attribute 'to_numpy'

# %%
# for i in (1, 2, 3, 4):
#     print(calculate_fid(sample_batch[-1].transpose(1, 0), sample_batch[i].transpose(1, 0)))
from dashboard.fid import calculate_fid
calculate_fid(sample_batch[-1].transpose(1, 0), torch.rand(126, 5))
# Out:
# torch.Size([126, 5])
# 13.731320295642748

# %%
wandb.finish()

# %%
torch.save(gen.model.gen.state_dict(), 'models/AIRI/TCN/test_save.pth')

# %%
wandb.init(
        project="test",  # Название проекта в W&B
        name=f"AIRI генерация log доходности акций",         # Название эксперимента
        
        config={              # Сохраняем гиперпараметры
            "learning_rate": 0.001,
            "batch_size": 0,
            "architecture": "TCN-GAN AIRI",
            "dataset": 'log-returs',
            "N_EPOCHS": 1,
        }
    )
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: avpotapov_5 (avpotapov_5-hse) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>C:\Users\an.v.potapov\Desktop\учеба\ФТИАД\курсач\gan_moex\wandb\run-20250516_190141-842xbx0x</code>
# Syncing run <strong><a href='https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x' target="_blank">AIRI генерация log доходности акций</a></strong> to <a href='https://wandb.ai/avpotapov_5-hse/test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/avpotapov_5-hse/test' target="_blank">https://wandb.ai/avpotapov_5-hse/test</a>
#  View run at <a href='https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x' target="_blank">https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
    
test_model = TCNGAN(
    target_columns=df_returns_real.columns.tolist(), 
    conditional_columns=[],
    hidden_dim=16,
    latent_dim=1,
    num_layers=2,
    kernel_size=3,
    num_disc_steps=3,
    window_size=126,
    batch_size=16,
    num_epochs=1,
    verbose=True,
    lr=0.001,
)
test_model.fit(df_returns_real)
wandb.finish()
# Out:
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# C:\Python\Lib\site-packages\lightning\pytorch\loggers\wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#
#   | Name | Type              | Params | Mode
# ---------------------------------------------------
# 0 | gen  | _TCNGenerator     | 2.5 K  | train
# 1 | disc | _TCNDiscriminator | 2.7 K  | train
# ---------------------------------------------------
# 5.3 K     Trainable params
# 0         Non-trainable params
# 5.3 K     Total params
# 0.021     Total estimated model params size (MB)
# 24        Modules in train mode
# 0         Modules in eval mode
# Training: |                                                                                                 | …
# `Trainer.fit` stopped: `max_epochs=1` reached.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>correlation_delta</td><td>▆▂▅▂▇█▅▁▅</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fid</td><td>▄▅▅▁▄▁▃█▄</td></tr><tr><td>mean_delta</td><td>▆▆▆▇█▄▄▃▁</td></tr><tr><td>train_disc_loss</td><td>▂▁▂▂▃▃▅▇█</td></tr><tr><td>train_gen_loss</td><td>▁▃▃▅▅▆▇▇█</td></tr><tr><td>trainer/global_step</td><td>▁▂▃▄▅▅▆▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>correlation_delta</td><td>0.83543</td></tr><tr><td>epoch</td><td>0</td></tr><tr><td>fid</td><td>6.50645</td></tr><tr><td>mean_delta</td><td>0.22838</td></tr><tr><td>train_disc_loss</td><td>0.69007</td></tr><tr><td>train_gen_loss</td><td>0.56223</td></tr><tr><td>trainer/global_step</td><td>143</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AIRI генерация log доходности акций</strong> at: <a href='https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x' target="_blank">https://wandb.ai/avpotapov_5-hse/test/runs/842xbx0x</a><br> View project at: <a href='https://wandb.ai/avpotapov_5-hse/test' target="_blank">https://wandb.ai/avpotapov_5-hse/test</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250516_190141-842xbx0x\logs</code>

# %%
# torch.save(gen.model.gen.state_dict(), '')
test_model.model.gen.load_state_dict(torch.load('models/AIRI/TCN/test_save.pth'))
# Out:
# <All keys matched successfully>

# %%
fake_data = test_model.sample(df_returns_real, n_samples=10)
fake_data[0].head()
# Out:
#                 LKOH      SBER     SBERP      VTBR      MOEX
# date
# 2013-04-05  0.016270 -0.035804  0.015416  0.066307  0.053003
# 2013-04-08 -0.005711 -0.028314  0.013687  0.031832  0.014898
# 2013-04-09  0.014258  0.003238  0.035848 -0.006480 -0.002224
# 2013-04-10  0.011610 -0.005799  0.018235 -0.000902 -0.007754
# 2013-04-11  0.003941  0.040849  0.016328 -0.009477 -0.010623

# %%
plt.figure(figsize=(12, 3))
for fake in fake_data:
    fake.cumsum().plot()

# %%
import torch
import torch.nn.functional as F


def vectorized_autocorrelation(x, lag, window_size):
    """
    Устойчивый расчет автокорреляции для 5D рядов
    Args:
        x: [batch_size, num_assets, seq_len]
        lag: лаг L (должен удовлетворять lag + window_size <= seq_len)
        window_size: N
    Returns:
        [batch_size, num_assets] (усредненная по окнам автокорреляция)
    """

    # 2. Создаем скользящие окна
    windows = x.unfold(2, window_size, 1)  # [batch, assets, num_windows, window_size]  
    
    # 3. Центрирование данных
    windows_centered = windows - windows.mean(dim=3, keepdim=True)
      
    # 4. Вычисление корреляции
    x_t = windows_centered[:, :, 0]
    x_t_lag = windows_centered[:, :, lag]
    # 5. Устойчивые вычисления
    cov = (x_t * x_t_lag).sum(dim=2)
    std_t = torch.norm(x_t, dim=2)
    std_t_lag = torch.norm(x_t_lag, dim=2)
    
    print(std_t * std_t_lag)
    print(cov )
    # 6. Специальная обработка нулевых стандартных отклонений
    autocorr = cov / (std_t * std_t_lag)
    
    return autocorr.mean(axis=0)**2 - (torch.ones((5)) * 0.7)**2

# %%
batch_size, num_assets, seq_len = 32, 5, 360
real_data = torch.randn(batch_size, num_assets, seq_len)
fake_data = torch.randn(batch_size, num_assets, seq_len)

# Расчет потерь
corr = vectorized_autocorrelation(real_data, 
                          lag=300, 
                          window_size=65)

print(corr)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 6
#       3 fake_data = torch.randn(batch_size, num_assets, seq_len)
#       5 # Расчет потерь
# ----> 6 corr = vectorized_autocorrelation(real_data,
#       7                           lag=300,
#       8                           window_size=65)
#      10 print(corr)
#
# Cell In[28], line 24, in vectorized_autocorrelation(x, lag, window_size)
#      22 # 4. Вычисление корреляции
#      23 x_t = windows_centered[:, :, 0]
# ---> 24 x_t_lag = windows_centered[:, :, lag]
#      25 # 5. Устойчивые вычисления
#      26 cov = (x_t * x_t_lag).sum(dim=2)
#
# IndexError: index 300 is out of bounds for dimension 2 with size 296

# %%
(torch.ones((5)) * 0.7)**2
# Out:
# tensor([0.4900, 0.4900, 0.4900, 0.4900, 0.4900])

# %%
a = torch.rand(1, 5, 10)
a
# Out:
# tensor([[[0.5507, 0.0541, 0.0273, 0.8446, 0.9515, 0.8564, 0.8077, 0.4318,
#           0.1164, 0.7927],
#          [0.0427, 0.7924, 0.7051, 0.2843, 0.3155, 0.5688, 0.6870, 0.8845,
#           0.9254, 0.0838],
#          [0.0120, 0.4428, 0.5890, 0.3189, 0.1533, 0.1292, 0.6010, 0.8147,
#           0.0045, 0.7844],
#          [0.5150, 0.9998, 0.0719, 0.8070, 0.7048, 0.3863, 0.1865, 0.5696,
#           0.6289, 0.9904],
#          [0.7923, 0.4406, 0.1700, 0.5278, 0.2688, 0.7421, 0.6236, 0.8011,
#           0.2801, 0.8729]]])

# %%
x = a.unfold(dimension=2, size=5, step=1)
x.shape
# Out:
# torch.Size([1, 5, 6, 5])

# %%
x
# Out:
# tensor([[[[0.5507, 0.0541, 0.0273, 0.8446, 0.9515],
#           [0.0541, 0.0273, 0.8446, 0.9515, 0.8564],
#           [0.0273, 0.8446, 0.9515, 0.8564, 0.8077],
#           [0.8446, 0.9515, 0.8564, 0.8077, 0.4318],
#           [0.9515, 0.8564, 0.8077, 0.4318, 0.1164],
#           [0.8564, 0.8077, 0.4318, 0.1164, 0.7927]],
#
#          [[0.0427, 0.7924, 0.7051, 0.2843, 0.3155],
#           [0.7924, 0.7051, 0.2843, 0.3155, 0.5688],
#           [0.7051, 0.2843, 0.3155, 0.5688, 0.6870],
#           [0.2843, 0.3155, 0.5688, 0.6870, 0.8845],
#           [0.3155, 0.5688, 0.6870, 0.8845, 0.9254],
#           [0.5688, 0.6870, 0.8845, 0.9254, 0.0838]],
#
#          [[0.0120, 0.4428, 0.5890, 0.3189, 0.1533],
#           [0.4428, 0.5890, 0.3189, 0.1533, 0.1292],
#           [0.5890, 0.3189, 0.1533, 0.1292, 0.6010],
#           [0.3189, 0.1533, 0.1292, 0.6010, 0.8147],
#           [0.1533, 0.1292, 0.6010, 0.8147, 0.0045],
#           [0.1292, 0.6010, 0.8147, 0.0045, 0.7844]],
#
#          [[0.5150, 0.9998, 0.0719, 0.8070, 0.7048],
#           [0.9998, 0.0719, 0.8070, 0.7048, 0.3863],
#           [0.0719, 0.8070, 0.7048, 0.3863, 0.1865],
#           [0.8070, 0.7048, 0.3863, 0.1865, 0.5696],
#           [0.7048, 0.3863, 0.1865, 0.5696, 0.6289],
#           [0.3863, 0.1865, 0.5696, 0.6289, 0.9904]],
#
#          [[0.7923, 0.4406, 0.1700, 0.5278, 0.2688],
#           [0.4406, 0.1700, 0.5278, 0.2688, 0.7421],
#           [0.1700, 0.5278, 0.2688, 0.7421, 0.6236],
#           [0.5278, 0.2688, 0.7421, 0.6236, 0.8011],
#           [0.2688, 0.7421, 0.6236, 0.8011, 0.2801],
#           [0.7421, 0.6236, 0.8011, 0.2801, 0.8729]]]])

# %%
a[..., 2:].unfold(dimension=2, size=2, step=3)
# Out:
# tensor([[[[0.1807, 0.0803],
#           [0.3877, 0.6295],
#           [0.5227, 0.7892]]]])
